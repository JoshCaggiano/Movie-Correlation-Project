# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

df = pd.read_csv(r'C:\Users\jcagg\OneDrive\Academic Yearly Downloads\Career\Portfolio\Movie Correlation in Python\movies.csv')

# %%
# Initial view of dataset

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Looking for missing data

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Drop all rows with missing data

df = df.dropna()

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
# Data types for columns

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# Changing data types for future analysis

df['budget'] = pd.to_numeric(df['budget'], errors='coerce').fillna(0).astype(int)
df['gross'] = pd.to_numeric(df['gross'], errors='coerce').fillna(0).astype(int) 

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int32
# gross         int32
# company      object
# runtime     float64
# dtype: object

# %%
# Create correct year column

df['yearcorrect'] = df['released'].str.split('[(,\s)]{1}').str[3]

df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score      votes  \
# ...

# %%
# Sorting by gross revenue

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name rating      genre  year  \
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13     Action  2015
# 7244                      Avengers: Infinity War  PG-13     Action  2018
# 7480                               The Lion King     PG  Animation  2019
# 6653                              Jurassic World  PG-13     Action  2015
# 6043                                The Avengers  PG-13     Action  2012
# ...                                          ...    ...        ...   ...
# 272                                     Parasite      R     Horror  1982
# 3203                                  Trojan War  PG-13     Comedy  1997
# 3045                                     Titanic  PG-13      Drama  1997
# 7445                           Avengers: Endgame  PG-13     Action  2019
# 5445                                      Avatar  PG-13     Action  2009
#
#                                released  score      votes         director  \
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates

df['company'].drop_duplicates().sort_values(ascending=False)
df.drop_duplicates().head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4690       6      6  1980      1303    8.4   927000.0      1795    2832
# 1  3927       6      1  1980      1126    5.8    65000.0      1578    1158
# 2  3639       4      0  1980      1358    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1126    7.7   221000.0       889    1413
# 4   730       6      4  1980      1169    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0   699       46  19000000   46998772     1426    146.0            1
# 1   214       47   4500000   58853106      452    104.0            1
# 2  1157       47  18000000  538375067      945    124.0            1
# 3  1474       47   3500000   83453539     1108     88.0            1
# 4   271       47   6000000   39846344     1083     98.0            1

# %%
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 3 films found where gross was negative - updating df to reflect only positive gross films

df = df[df['gross'] >= 0]

# %%
# Re-checking scatter plot

plt.scatter(x=df['budget'], y=df['gross'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Formatting scatter plot

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Gross Earnings')

plt.ylabel('Budget for Film')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Starting to look at correlation

df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.055746  0.205973  0.328175  0.283780  0.074210
# score    0.055746  1.000000  0.473405  0.067334  0.221701  0.412577
# votes    0.205973  0.473405  1.000000  0.431864  0.613791  0.345443
# budget   0.328175  0.067334  0.431864  1.000000  0.743536  0.311063
# gross    0.283780  0.221701  0.613791  0.743536  1.000000  0.261947
# runtime  0.074210  0.412577  0.345443  0.311063  0.261947  1.000000

# %%
# High correlation between budget and gross

# %%
# Visualizing correlation matrix

correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Variables')

plt.xlabel('Movie Variables')

plt.ylabel('Movie Variables')

plt.show()

# %%
# Make all non-numeric variables int numeric variables to include in matrix

df_numerized = df

for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name] = df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4690       6      6  1980      1303    8.4   927000.0      1795    2832
# 1  3927       6      1  1980      1126    5.8    65000.0      1578    1158
# 2  3639       4      0  1980      1358    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1126    7.7   221000.0       889    1413
# 4   730       6      4  1980      1169    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime  yearcorrect
# 0   699       46  19000000   46998772     1426    146.0            1
# 1   214       47   4500000   58853106      452    104.0            1
# 2  1157       47  18000000  538375067      945    124.0            1
# 3  1474       47   3500000   83453539     1108     88.0            1
# 4   271       47   6000000   39846344     1083     98.0            1

# %%
correlation_matrix = df_numerized.corr()

sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Variables')

plt.xlabel('Movie Variables')

plt.ylabel('Movie Variables')

plt.show()

# %%
# High correlation between gross and budget
# High correlation between gross and votes
# No statistical significance on non-numeric variables
